# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl', 'rb'))

# %%
df
# Out:
#      match_id batting_team  runs bowling_team  ball player_dismissed  \
# 0           2    Australia     0     Pakistan   0.1                0
# 1           2    Australia     0     Pakistan   0.2                0
# 2           2    Australia     0     Pakistan   0.3                0
# 3           2    Australia     0     Pakistan   0.4                0
# 4           2    Australia     1     Pakistan   0.5                0
# ..        ...          ...   ...          ...   ...              ...
# 307      1798      Ireland     4  Afghanistan  49.2                0
# 308      1798      Ireland     4  Afghanistan  49.3                0
# 309      1798      Ireland     1  Afghanistan  49.4                0
# 310      1798      Ireland     1  Afghanistan  49.5                0
# 311      1798      Ireland     0  Afghanistan  49.6                0
#
#          city                                   venue
# 0    Brisbane  Brisbane Cricket Ground, Woolloongabba
# 1    Brisbane  Brisbane Cricket Ground, Woolloongabba
# 2    Brisbane  Brisbane Cricket Ground, Woolloongabba
# 3    Brisbane  Brisbane Cricket Ground, Woolloongabba
# 4    Brisbane  Brisbane Cricket Ground, Woolloongabba
# ..        ...                                     ...
# 307   Belfast    Civil Service Cricket Club, Stormont
# 308   Belfast    Civil Service Cricket Club, Stormont
# 309   Belfast    Civil Service Cricket Club, Stormont
# 310   Belfast    Civil Service Cricket Club, Stormont
# 311   Belfast    Civil Service Cricket Club, Stormont
#
# [348235 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id                0
# batting_team            0
# runs                    0
# bowling_team            0
# ball                    0
# player_dismissed        0
# city                64411
# venue                   0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Sydney Cricket Ground                      9600
# Rangiri Dambulla International Stadium     8366
# Adelaide Oval                              8035
# Melbourne Cricket Ground                   7468
# Harare Sports Club                         7031
# Sharjah Cricket Stadium                    6297
# Dubai International Cricket Stadium        6234
# Pallekele International Cricket Stadium    6100
# Rawalpindi Cricket Stadium                 1201
# Multan Cricket Stadium                     1199
# Chittagong Divisional Stadium               594
# Perth Stadium                               526
# Dubai Sports City Cricket Stadium           518
# Bulawayo Athletic Club                      312
# Sharjah Cricket Association Stadium         303
# Sheikhupura Stadium                         291
# Galle International Stadium                 208
# Queenstown Events Centre                    128
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
cities
# Out:
# array(['Brisbane', 'Brisbane', 'Brisbane', ..., 'Belfast', 'Belfast',
#        'Belfast'], dtype=object)

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# runs                0
# bowling_team        0
# ball                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns = ['venue'], inplace = True )

# %%
df['city'].value_counts()
# Out:
# London                16571
# Colombo               16060
# Mirpur                11583
# Abu Dhabi             10297
# Sydney                 9908
#                       ...
# Galle                   208
# Thiruvananthapuram      198
# Gros Islet              179
# Queenstown              128
# Providence               80
# Name: city, Length: 116, dtype: int64

# %%
df
# Out:
#      match_id batting_team  runs bowling_team  ball player_dismissed      city
# 0           2    Australia     0     Pakistan   0.1                0  Brisbane
# 1           2    Australia     0     Pakistan   0.2                0  Brisbane
# 2           2    Australia     0     Pakistan   0.3                0  Brisbane
# 3           2    Australia     0     Pakistan   0.4                0  Brisbane
# 4           2    Australia     1     Pakistan   0.5                0  Brisbane
# ..        ...          ...   ...          ...   ...              ...       ...
# 307      1798      Ireland     4  Afghanistan  49.2                0   Belfast
# 308      1798      Ireland     4  Afghanistan  49.3                0   Belfast
# 309      1798      Ireland     1  Afghanistan  49.4                0   Belfast
# 310      1798      Ireland     1  Afghanistan  49.5                0   Belfast
# 311      1798      Ireland     0  Afghanistan  49.6                0   Belfast
#
# [348235 rows x 7 columns]

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 1800 ].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\1598928411.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\1598928411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team  runs bowling_team  ball player_dismissed  \
# 0           2    Australia     0     Pakistan   0.1                0
# 1           2    Australia     0     Pakistan   0.2                0
# 2           2    Australia     0     Pakistan   0.3                0
# 3           2    Australia     0     Pakistan   0.4                0
# 4           2    Australia     1     Pakistan   0.5                0
# ..        ...          ...   ...          ...   ...              ...
# 307      1798      Ireland     4  Afghanistan  49.2                0
# 308      1798      Ireland     4  Afghanistan  49.3                0
# 309      1798      Ireland     1  Afghanistan  49.4                0
# 310      1798      Ireland     1  Afghanistan  49.5                0
# 311      1798      Ireland     0  Afghanistan  49.6                0
#
#          city  current_score
# 0    Brisbane              0
# 1    Brisbane              0
# 2    Brisbane              0
# 3    Brisbane              0
# 4    Brisbane              1
# ..        ...            ...
# 307   Belfast            259
# 308   Belfast            263
# 309   Belfast            264
# 310   Belfast            265
# 311   Belfast            265
#
# [304817 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\1757844946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\1757844946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df
# Out:
#      match_id batting_team  runs bowling_team  ball player_dismissed  \
# 0           2    Australia     0     Pakistan   0.1                0
# 1           2    Australia     0     Pakistan   0.2                0
# 2           2    Australia     0     Pakistan   0.3                0
# 3           2    Australia     0     Pakistan   0.4                0
# 4           2    Australia     1     Pakistan   0.5                0
# ..        ...          ...   ...          ...   ...              ...
# 307      1798      Ireland     4  Afghanistan  49.2                0
# 308      1798      Ireland     4  Afghanistan  49.3                0
# 309      1798      Ireland     1  Afghanistan  49.4                0
# 310      1798      Ireland     1  Afghanistan  49.5                0
# 311      1798      Ireland     0  Afghanistan  49.6                0
#
#          city  current_score over ball_no
# 0    Brisbane              0    0       1
# 1    Brisbane              0    0       2
# 2    Brisbane              0    0       3
# 3    Brisbane              0    0       4
# 4    Brisbane              1    0       5
# ..        ...            ...  ...     ...
# 307   Belfast            259   49       2
# 308   Belfast            263   49       3
# 309   Belfast            264   49       4
# 310   Belfast            265   49       5
# 311   Belfast            265   49       6
#
# [304817 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\1229405954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')

# %%
df
# Out:
#      match_id batting_team  runs bowling_team  ball player_dismissed  \
# 0           2    Australia     0     Pakistan   0.1                0
# 1           2    Australia     0     Pakistan   0.2                0
# 2           2    Australia     0     Pakistan   0.3                0
# 3           2    Australia     0     Pakistan   0.4                0
# 4           2    Australia     1     Pakistan   0.5                0
# ..        ...          ...   ...          ...   ...              ...
# 307      1798      Ireland     4  Afghanistan  49.2                0
# 308      1798      Ireland     4  Afghanistan  49.3                0
# 309      1798      Ireland     1  Afghanistan  49.4                0
# 310      1798      Ireland     1  Afghanistan  49.5                0
# 311      1798      Ireland     0  Afghanistan  49.6                0
#
#          city  current_score over ball_no  balls_bowled
# 0    Brisbane              0    0       1             1
# 1    Brisbane              0    0       2             2
# 2    Brisbane              0    0       3             3
# 3    Brisbane              0    0       4             4
# 4    Brisbane              1    0       5             5
# ..        ...            ...  ...     ...           ...
# 307   Belfast            259   49       2           296
# 308   Belfast            263   49       3           297
# 309   Belfast            264   49       4           298
# 310   Belfast            265   49       5           299
# 311   Belfast            265   49       6           300
#
# [304817 rows x 11 columns]

# %%
df['balls_left'] = 300 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\635635650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 300 - df['balls_bowled']
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\635635650.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df
# Out:
#      match_id batting_team  runs bowling_team  ball player_dismissed  \
# 0           2    Australia     0     Pakistan   0.1                0
# 1           2    Australia     0     Pakistan   0.2                0
# 2           2    Australia     0     Pakistan   0.3                0
# 3           2    Australia     0     Pakistan   0.4                0
# 4           2    Australia     1     Pakistan   0.5                0
# ..        ...          ...   ...          ...   ...              ...
# 307      1798      Ireland     4  Afghanistan  49.2                0
# 308      1798      Ireland     4  Afghanistan  49.3                0
# 309      1798      Ireland     1  Afghanistan  49.4                0
# 310      1798      Ireland     1  Afghanistan  49.5                0
# 311      1798      Ireland     0  Afghanistan  49.6                0
#
#          city  current_score over ball_no  balls_bowled  balls_left
# 0    Brisbane              0    0       1             1         299
# 1    Brisbane              0    0       2             2         298
# 2    Brisbane              0    0       3             3         297
# 3    Brisbane              0    0       4             4         296
# 4    Brisbane              1    0       5             5         295
# ..        ...            ...  ...     ...           ...         ...
# 307   Belfast            259   49       2           296           4
# 308   Belfast            263   49       3           297           3
# 309   Belfast            264   49       4           298           2
# 310   Belfast            265   49       5           299           1
# 311   Belfast            265   49       6           300           0
#
# [304817 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\2816823994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\2816823994.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\2816823994.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\2816823994.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']

# %%
df
# Out:
#      match_id batting_team  runs bowling_team  ball  player_dismissed  \
# 0           2    Australia     0     Pakistan   0.1                 0
# 1           2    Australia     0     Pakistan   0.2                 0
# 2           2    Australia     0     Pakistan   0.3                 0
# 3           2    Australia     0     Pakistan   0.4                 0
# 4           2    Australia     1     Pakistan   0.5                 0
# ..        ...          ...   ...          ...   ...               ...
# 307      1798      Ireland     4  Afghanistan  49.2                 5
# 308      1798      Ireland     4  Afghanistan  49.3                 5
# 309      1798      Ireland     1  Afghanistan  49.4                 5
# 310      1798      Ireland     1  Afghanistan  49.5                 5
# 311      1798      Ireland     0  Afghanistan  49.6                 5
#
#          city  current_score over ball_no  balls_bowled  balls_left
# 0    Brisbane              0    0       1             1         299
# 1    Brisbane              0    0       2             2         298
# 2    Brisbane              0    0       3             3         297
# 3    Brisbane              0    0       4             4         296
# 4    Brisbane              1    0       5             5         295
# ..        ...            ...  ...     ...           ...         ...
# 307   Belfast            259   49       2           296           4
# 308   Belfast            263   49       3           297           3
# 309   Belfast            264   49       4           298           2
# 310   Belfast            265   49       5           299           1
# 311   Belfast            265   49       6           300           0
#
# [304817 rows x 12 columns]

# %%
df['wicket_left'] = 10 - df['player_dismissed']
df
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\352052190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wicket_left'] = 10 - df['player_dismissed']
#      match_id batting_team  runs bowling_team  ball  player_dismissed  \
# 0           2    Australia     0     Pakistan   0.1                 0
# 1           2    Australia     0     Pakistan   0.2                 0
# 2           2    Australia     0     Pakistan   0.3                 0
# 3           2    Australia     0     Pakistan   0.4                 0
# 4           2    Australia     1     Pakistan   0.5                 0
# ..        ...          ...   ...          ...   ...               ...
# 307      1798      Ireland     4  Afghanistan  49.2                 5
# 308      1798      Ireland     4  Afghanistan  49.3                 5
# 309      1798      Ireland     1  Afghanistan  49.4                 5
# 310      1798      Ireland     1  Afghanistan  49.5                 5
# 311      1798      Ireland     0  Afghanistan  49.6                 5
#
#          city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Brisbane              0    0       1             1         299
# 1    Brisbane              0    0       2             2         298
# 2    Brisbane              0    0       3             3         297
# 3    Brisbane              0    0       4             4         296
# 4    Brisbane              1    0       5             5         295
# ..        ...            ...  ...     ...           ...         ...
# 307   Belfast            259   49       2           296           4
# 308   Belfast            263   49       3           297           3
# 309   Belfast            264   49       4           298           2
# 310   Belfast            265   49       5           299           1
# 311   Belfast            265   49       6           300           0
#
#      wicket_left
# 0             10
# 1             10
# 2             10
# 3             10
# 4             10
# ..           ...
# 307            5
# 308            5
# 309            5
# 310            5
# 311            5
#
# [304817 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
df
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\1226876470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']
#      match_id batting_team  runs bowling_team  ball  player_dismissed  \
# 0           2    Australia     0     Pakistan   0.1                 0
# 1           2    Australia     0     Pakistan   0.2                 0
# 2           2    Australia     0     Pakistan   0.3                 0
# 3           2    Australia     0     Pakistan   0.4                 0
# 4           2    Australia     1     Pakistan   0.5                 0
# ..        ...          ...   ...          ...   ...               ...
# 307      1798      Ireland     4  Afghanistan  49.2                 5
# 308      1798      Ireland     4  Afghanistan  49.3                 5
# 309      1798      Ireland     1  Afghanistan  49.4                 5
# 310      1798      Ireland     1  Afghanistan  49.5                 5
# 311      1798      Ireland     0  Afghanistan  49.6                 5
#
#          city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Brisbane              0    0       1             1         299
# 1    Brisbane              0    0       2             2         298
# 2    Brisbane              0    0       3             3         297
# 3    Brisbane              0    0       4             4         296
# 4    Brisbane              1    0       5             5         295
# ..        ...            ...  ...     ...           ...         ...
# 307   Belfast            259   49       2           296           4
# 308   Belfast            263   49       3           297           3
# 309   Belfast            264   49       4           298           2
# 310   Belfast            265   49       5           299           1
# 311   Belfast            265   49       6           300           0
#
#      wicket_left       crr
# 0             10  0.000000
# 1             10  0.000000
# 2             10  0.000000
# 3             10  0.000000
# 4             10  1.200000
# ..           ...       ...
# 307            5  5.250000
# 308            5  5.313131
# 309            5  5.315436
# 310            5  5.317726
# 311            5  5.300000
#
# [304817 rows x 14 columns]

# %%
groups = df.groupby('match_id')
match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window = 30).sum()['runs'].values.tolist())
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\3649387189.py:5: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window = 30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df
# Out:
#      match_id batting_team  runs bowling_team  ball  player_dismissed  \
# 0           2    Australia     0     Pakistan   0.1                 0
# 1           2    Australia     0     Pakistan   0.2                 0
# 2           2    Australia     0     Pakistan   0.3                 0
# 3           2    Australia     0     Pakistan   0.4                 0
# 4           2    Australia     1     Pakistan   0.5                 0
# ..        ...          ...   ...          ...   ...               ...
# 307      1798      Ireland     4  Afghanistan  49.2                 5
# 308      1798      Ireland     4  Afghanistan  49.3                 5
# 309      1798      Ireland     1  Afghanistan  49.4                 5
# 310      1798      Ireland     1  Afghanistan  49.5                 5
# 311      1798      Ireland     0  Afghanistan  49.6                 5
#
#          city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Brisbane              0    0       1             1         299
# 1    Brisbane              0    0       2             2         298
# 2    Brisbane              0    0       3             3         297
# 3    Brisbane              0    0       4             4         296
# 4    Brisbane              1    0       5             5         295
# ..        ...            ...  ...     ...           ...         ...
# 307   Belfast            259   49       2           296           4
# 308   Belfast            263   49       3           297           3
# 309   Belfast            264   49       4           298           2
# 310   Belfast            265   49       5           299           1
# 311   Belfast            265   49       6           300           0
#
#      wicket_left       crr  last_five
# 0             10  0.000000        NaN
# 1             10  0.000000        NaN
# 2             10  0.000000        NaN
# 3             10  0.000000        NaN
# 4             10  1.200000        NaN
# ..           ...       ...        ...
# 307            5  5.250000       60.0
# 308            5  5.313131       63.0
# 309            5  5.315436       64.0
# 310            5  5.317726       63.0
# 311            5  5.300000       62.0
#
# [304817 rows x 15 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')
# Out:
# C:\Users\divak\AppData\Local\Temp\ipykernel_1276\3687880561.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#         match_id  runs_x batting_team  runs_y bowling_team  ball  \
# 0              2     268    Australia       0     Pakistan   0.1
# 1              2     268    Australia       0     Pakistan   0.2
# 2              2     268    Australia       0     Pakistan   0.3
# 3              2     268    Australia       0     Pakistan   0.4
# 4              2     268    Australia       1     Pakistan   0.5
# ...          ...     ...          ...     ...          ...   ...
# 304812      1798     265      Ireland       4  Afghanistan  49.2
# 304813      1798     265      Ireland       4  Afghanistan  49.3
# 304814      1798     265      Ireland       1  Afghanistan  49.4
# 304815      1798     265      Ireland       1  Afghanistan  49.5
# 304816      1798     265      Ireland       0  Afghanistan  49.6
#
#         player_dismissed      city  current_score over ball_no  balls_bowled  \
# 0                      0  Brisbane              0    0       1             1
# 1                      0  Brisbane              0    0       2             2
# 2                      0  Brisbane              0    0       3             3
# 3                      0  Brisbane              0    0       4             4
# 4                      0  Brisbane              1    0       5             5
# ...                  ...       ...            ...  ...     ...           ...
# 304812                 5   Belfast            259   49       2           296
# 304813                 5   Belfast            263   49       3           297
# 304814                 5   Belfast            264   49       4           298
# 304815                 5   Belfast            265   49       5           299
# 304816                 5   Belfast            265   49       6           300
#
#         balls_left  wicket_left       crr  last_five
# 0              299           10  0.000000        NaN
# 1              298           10  0.000000        NaN
# 2              297           10  0.000000        NaN
# 3              296           10  0.000000        NaN
# 4              295           10  1.200000        NaN
# ...            ...          ...       ...        ...
# 304812           4            5  5.250000       60.0
# 304813           3            5  5.313131       63.0
# 304814           2            5  5.315436       64.0
# 304815           1            5  5.317726       63.0
# 304816           0            5  5.300000       62.0
#
# [304817 rows x 16 columns]

# %%
final_df = final_df[['batting_team','current_score','bowling_team','ball', 'wicket_left', 'crr','last_five', 'runs_x',]]

# %%
final_df
# Out:
#        batting_team  current_score bowling_team  ball  wicket_left       crr  \
# 29        Australia             13     Pakistan   4.5            8  2.689655
# 30        Australia             13     Pakistan   4.6            8  2.600000
# 31        Australia             14     Pakistan   5.1            8  2.709677
# 32        Australia             15     Pakistan   5.2            8  2.812500
# 33        Australia             16     Pakistan   5.3            8  2.909091
# ...             ...            ...          ...   ...          ...       ...
# 304812      Ireland            259  Afghanistan  49.2            5  5.250000
# 304813      Ireland            263  Afghanistan  49.3            5  5.313131
# 304814      Ireland            264  Afghanistan  49.4            5  5.315436
# 304815      Ireland            265  Afghanistan  49.5            5  5.317726
# 304816      Ireland            265  Afghanistan  49.6            5  5.300000
#
#         last_five  runs_x
# 29           13.0     268
# 30           13.0     268
# 31           14.0     268
# 32           15.0     268
# 33           16.0     268
# ...           ...     ...
# 304812       60.0     265
# 304813       63.0     265
# 304814       64.0     265
# 304815       63.0     265
# 304816       62.0     265
#
# [274215 rows x 8 columns]

# %%
final_df.dropna(inplace = True)

# %%
final_df
# Out:
#        batting_team  current_score bowling_team  ball  wicket_left       crr  \
# 29        Australia             13     Pakistan   4.5            8  2.689655
# 30        Australia             13     Pakistan   4.6            8  2.600000
# 31        Australia             14     Pakistan   5.1            8  2.709677
# 32        Australia             15     Pakistan   5.2            8  2.812500
# 33        Australia             16     Pakistan   5.3            8  2.909091
# ...             ...            ...          ...   ...          ...       ...
# 304812      Ireland            259  Afghanistan  49.2            5  5.250000
# 304813      Ireland            263  Afghanistan  49.3            5  5.313131
# 304814      Ireland            264  Afghanistan  49.4            5  5.315436
# 304815      Ireland            265  Afghanistan  49.5            5  5.317726
# 304816      Ireland            265  Afghanistan  49.6            5  5.300000
#
#         last_five  runs_x
# 29           13.0     268
# 30           13.0     268
# 31           14.0     268
# 32           15.0     268
# 33           16.0     268
# ...           ...     ...
# 304812       60.0     265
# 304813       63.0     265
# 304814       64.0     265
# 304815       63.0     265
# 304816       62.0     265
#
# [274215 rows x 8 columns]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#         batting_team  current_score  bowling_team  ball  wicket_left  \
# 155386   New Zealand            117  South Africa  30.6            7
# 261975     Sri Lanka            244       England  44.1            6
# 2124        Zimbabwe             38         India  12.2            9
# 3209     New Zealand             53  South Africa  12.5            9
# 86418      Sri Lanka            183      Pakistan  43.3            4
# ...              ...            ...           ...   ...          ...
# 200710     Sri Lanka            156         India  33.5            7
# 231608         India            140      Pakistan  37.1            3
# 47629      Sri Lanka            232         India  44.5            5
# 5389    South Africa            158      Pakistan  40.5            4
# 7441        Pakistan            176         India  28.6            9
#
#              crr  last_five  runs_x
# 155386  3.774194       18.0     214
# 261975  5.524528       27.0     300
# 2124    3.081081       17.0     123
# 3209    4.129870       21.0     289
# 86418   4.206897       31.0     224
# ...          ...        ...     ...
# 200710  4.610837       24.0     236
# 231608  3.766816       17.0     167
# 47629   5.174721       31.0     264
# 5389    3.869388       21.0     219
# 7441    6.068966       45.0     338
#
# [274215 rows x 8 columns]

# %%
final_df.sample(2)
# Out:
#        batting_team  current_score bowling_team  ball  wicket_left       crr  \
# 59938     Australia             27     Pakistan   6.4           10  4.050000
# 236716      England             24    Australia   5.3           10  4.363636
#
#         last_five  runs_x
# 59938        18.0     277
# 236716       21.0     316

# %%
X = final_df.drop(columns = ['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state = 1)

# %%
X_train
# Out:
#         batting_team  current_score  bowling_team  ball  wicket_left  \
# 148777      Pakistan             57     Australia  19.3            8
# 23113    New Zealand            222   West Indies  39.8            5
# 39397      Sri Lanka            153  South Africa  35.2            1
# 136666     Australia             99  South Africa  28.5            4
# 131153         India            278      Pakistan  47.3            4
# ...              ...            ...           ...   ...          ...
# 159972   New Zealand             49     Australia   5.6           10
# 258308      Pakistan            188     Sri Lanka  44.5            3
# 5180    South Africa             25      Pakistan   5.6           10
# 86250      Sri Lanka             63      Pakistan  15.4            9
# 81338      Australia             42     Sri Lanka   8.5            7
#
#              crr  last_five
# 148777  2.923077       13.0
# 23113   5.504132       24.0
# 39397   4.330189       35.0
# 136666  3.433526       13.0
# 131153  5.852632       29.0
# ...          ...        ...
# 159972  8.166667       42.0
# 258308  4.193309       15.0
# 5180    4.166667       20.0
# 86250   4.021277       10.0
# 81338   4.754717       22.0
#
# [219372 rows x 7 columns]

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\divak\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: numpy in c:\users\divak\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\divak\anaconda3\lib\site-packages (from xgboost) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\divak\anaconda3\lib\site-packages (1.3.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.17.3 in c:\users\divak\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\divak\anaconda3\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\divak\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\divak\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse = False,drop = 'first'),['batting_team', 'bowling_team'])
]
,remainder = 'passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\divak\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9430446893268422
# 7.1293851566782465

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
eligible_cities
# Out:
# ['London',
#  'Colombo',
#  'Mirpur',
#  'Abu Dhabi',
#  'Sydney',
#  'Melbourne',
#  'Rangiri',
#  'Adelaide',
#  'Centurion',
#  'Dubai',
#  'Harare',
#  'Perth',
#  'Sharjah',
#  'Johannesburg',
#  'Pallekele',
#  'Brisbane',
#  'Southampton',
#  'Birmingham',
#  'Manchester',
#  'Port Elizabeth',
#  'Guyana',
#  'Durban',
#  'Cape Town',
#  'Nottingham',
#  'Leeds',
#  'Antigua',
#  'Bulawayo',
#  'St Lucia',
#  'Cardiff',
#  'Jamaica',
#  'Auckland',
#  'Chandigarh',
#  'Karachi',
#  'Trinidad',
#  'Wellington',
#  'Barbados',
#  'Hambantota',
#  'Mumbai',
#  'Chester-le-Street',
#  'Delhi',
#  'St Kitts',
#  'Nagpur',
#  'Ahmedabad',
#  'Hobart',
#  'Napier',
#  'Jaipur',
#  'Chennai',
#  'Bristol',
#  'Lahore',
#  'Visakhapatnam',
#  'Grenada',
#  'Hamilton',
#  'Rajkot',
#  'St Vincent',
#  'Belfast',
#  'Christchurch',
#  'Bangalore',
#  'Kolkata',
#  'Bloemfontein',
#  'Hyderabad',
#  'Cuttack']
